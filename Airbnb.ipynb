# %%
Names = []
Reviews = []
Prices = []
Links = []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.airbnb.co.in/s/North-Goa--Goa/homes?date_picker_type=calendar&source=structured_search_input_header&search_type=AUTOSUGGEST&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-11-01&monthly_length=3&monthly_end_date=2026-02-01&price_filter_input_type=1&price_filter_num_nights=5&channel=EXPLORE&refinement_paths%5B%5D=%2Fhomes&place_id=ChIJMaD6Uu3AvzsR0E3VfowKzRs&checkin=2025-12-01&checkout=2025-12-07"

r = requests.get(url)

soup = BeautifulSoup(r.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# ...

# %%
main = soup.find("div", {"class":"f1535fuh atm_vy_22di98__1v156lz atm_lk_wse1wl__1v156lz atm_ll_wse1wl__1v156lz atm_vy_1osr8yv__qky54b atm_lk_1au8wfg__qky54b atm_ll_1au8wfg__qky54b atm_vy_22di98__jx8car atm_j3_15lnffs__jx8car dir dir-ltr"})

sub = main.find_all("div",{"class":"c965t3n atm_9s_11p5wf0 atm_dz_1osqo2v dir dir-ltr"})

for i in sub:
    Name = i.find("div",{"class":"t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_hfv0h6 atm_cs_1mexzig atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr"})
    Names.append(Name.text)

    Review = i.find("span",{"class":"a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_vv_1q9ccgz atm_vy_t94yts au0q88m atm_mk_stnw88 atm_tk_idpfg4 dir dir-ltr"})
    Reviews.append(Review.text)

    Price = i.find("div",{"class":"_10d7v0r"})
    Prices.append(Price.text)

    Link = i.find("a",{"class":"rfexzly atm_9s_1ulexfb atm_7l_1j28jx2 atm_e2_1osqo2v dir dir-ltr"})
    Links.append("https://www.airbnb.co.in" + Link.get("href"))
# Out:
# ['https://www.airbnb.co.in/rooms/1239036936549792305?check_in=2025-12-01&check_out=2025-12-07&search_mode=regular_search&source_impression_id=p3_1760366199_P36vVGpUW6bLLtg6&previous_page_section_name=1000&federated_search_id=60c84f09-da13-4e01-83ce-15c404ba7e65',
#  'https://www.airbnb.co.in/rooms/1329045222149595136?check_in=2025-12-01&check_out=2025-12-07&search_mode=regular_search&source_impression_id=p3_1760366199_P38WOFXG0wnzJ48p&previous_page_section_name=1000&federated_search_id=60c84f09-da13-4e01-83ce-15c404ba7e65',
#  'https://www.airbnb.co.in/rooms/1315619188852974647?check_in=2025-12-01&check_out=2025-12-07&search_mode=regular_search&source_impression_id=p3_1760366199_P3zWJV3iTqEZh8hc&previous_page_section_name=1000&federated_search_id=60c84f09-da13-4e01-83ce-15c404ba7e65',
# ...

# %%
df = pd.DataFrame({"Names":Names, "Reviews":Reviews, "Prices":Prices, "Links":Links})
df
# Out:
#                            Names                                     Reviews  \
# 0              Flat in Calangute  4.75 out of 5 average rating,  134 reviews
# 1         Apartment in Calangute   4.64 out of 5 average rating,  33 reviews
# 2               Flat in Candolim   4.95 out of 5 average rating,  22 reviews
# 3                 Flat in Siolim   4.95 out of 5 average rating,  19 reviews
# 4               Flat in Candolim     5.0 out of 5 average rating,  3 reviews
# 5                 Flat in Siolim   4.86 out of 5 average rating,  35 reviews
# 6            Apartment in Siolim   4.91 out of 5 average rating,  35 reviews
# 7        Flat in Penha de França    4.83 out of 5 average rating,  6 reviews
# 8            Apartment in Siolim   4.76 out of 5 average rating,  76 reviews
# 9              Flat in Calangute    5.0 out of 5 average rating,  11 reviews
# 10             Flat in Calangute   4.94 out of 5 average rating,  17 reviews
# ...

# %%
Names = []
Reviews = []
Prices = []
Links = []
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = "https://www.airbnb.co.in/s/Manali--Himachal-Pradesh/homes?date_picker_type=calendar&source=structured_search_input_header&search_type=AUTOSUGGEST&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-11-01&monthly_length=3&monthly_end_date=2026-02-01&price_filter_input_type=1&price_filter_num_nights=6&channel=EXPLORE&checkin=2025-12-01&checkout=2025-12-07&refinement_paths%5B%5D=%2Fhomes&place_id=ChIJP9A_FgiHBDkRzXZQvg6oKYE"

for i in range(1,10):
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text, "html.parser")
    
    main = soup.find("div", {"class":"f1535fuh atm_vy_22di98__1v156lz atm_lk_wse1wl__1v156lz atm_ll_wse1wl__1v156lz atm_vy_1osr8yv__qky54b atm_lk_1au8wfg__qky54b atm_ll_1au8wfg__qky54b atm_vy_22di98__jx8car atm_j3_15lnffs__jx8car dir dir-ltr"})

    sub = main.find_all("div",{"class":"c965t3n atm_9s_11p5wf0 atm_dz_1osqo2v dir dir-ltr"})
    
    for i in sub:
        Name = i.find("div",{"class":"t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_hfv0h6 atm_cs_1mexzig atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr"})
        Names.append(Name.text)
    
        try:
            Review = i.find("span",{"class":"a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_vv_1q9ccgz atm_vy_t94yts au0q88m atm_mk_stnw88 atm_tk_idpfg4 dir dir-ltr"})
            Reviews.append(Review.text)
        except:
            Reviews.append(np.nan)
    
        Price = i.find("div",{"class":"_10d7v0r"})
        Prices.append(Price.text)
    
        Link = i.find("a",{"class":"rfexzly atm_9s_1ulexfb atm_7l_1j28jx2 atm_e2_1osqo2v dir dir-ltr"})
        Links.append("https://www.airbnb.co.in" + Link.get("href"))
    
    
    np = soup.find("a",{"class":"l1ovpqvx atm_npmupv_14b5rvc_10saat9 atm_4s4swg_18xq13z_10saat9 atm_u9em2p_1r3889l_10saat9 atm_1ezpcqw_1u41vd9_10saat9 atm_fyjbsv_c4n71i_10saat9 atm_1rna0z7_1uk391_10saat9 c1ytbx3a atm_mk_h2mmj6 atm_9s_1txwivl atm_h_1h6ojuz atm_fc_1h6ojuz atm_bb_idpfg4 atm_26_1j28jx2 atm_3f_glywfm atm_7l_b0j8a8 atm_gi_idpfg4 atm_l8_idpfg4 atm_uc_oxy5qq atm_kd_glywfm atm_gz_opxopj atm_uc_glywfm__1rrf6b5 atm_26_ppd4by_1rqz0hn_uv4tnr atm_tr_kv3y6q_csw3t1 atm_26_ppd4by_1ul2smo atm_3f_glywfm_jo46a5 atm_l8_idpfg4_jo46a5 atm_gi_idpfg4_jo46a5 atm_3f_glywfm_1icshfk atm_kd_glywfm_19774hq atm_70_glywfm_1w3cfyq atm_uc_1wx0j5_9xuho3 atm_70_1j5h5ka_9xuho3 atm_26_ppd4by_9xuho3 atm_uc_glywfm_9xuho3_1rrf6b5 atm_7l_156bl0x_1o5j5ji atm_9j_13gfvf7_1o5j5ji atm_26_1j28jx2_154oz7f atm_92_1yyfdc7_vmtskl atm_9s_1ulexfb_vmtskl atm_mk_stnw88_vmtskl atm_tk_1ssbidh_vmtskl atm_fq_1ssbidh_vmtskl atm_tr_pryxvc_vmtskl atm_vy_1vi7ecw_vmtskl atm_e2_1vi7ecw_vmtskl atm_5j_1ssbidh_vmtskl atm_mk_h2mmj6_1ko0jae dir dir-ltr"})
    cnp = "https://www.airbnb.co.in" + np.get("href")
    print(cnp)
    url = cnp
# Out:
# https://www.airbnb.co.in/s/Manali--Himachal-Pradesh/homes?date_picker_type=calendar&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2025-11-01&monthly_length=3&monthly_end_date=2026-02-01&price_filter_input_type=1&price_filter_num_nights=6&channel=EXPLORE&checkin=2025-12-01&checkout=2025-12-07&refinement_paths%5B%5D=%2Fhomes&place_id=ChIJP9A_FgiHBDkRzXZQvg6oKYE&query=Manali%2C%20Himachal%20Pradesh&search_mode=regular_search&federated_search_session_id=ac4de4c3-5490-4c40-8567-a19d6006bf59&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D
# ...

# %%
df = pd.DataFrame({"Names":Names, "Reviews":Reviews, "Prices":Prices, "Links":Links})
df
# Out:
#                            Names                                     Reviews  \
# 0                 Home in Manali   4.98 out of 5 average rating,  49 reviews
# 1                Room in Vashist   4.97 out of 5 average rating,  34 reviews
# 2                 Room in Manali    4.8 out of 5 average rating,  69 reviews
# 3           Farm stay in Vashist  4.98 out of 5 average rating,  220 reviews
# 4                 Flat in Manali                           New place to stay
# ..                           ...                                         ...
# 157            Cottage in Manali   4.91 out of 5 average rating,  33 reviews
# 158               Home in Manali     5.0 out of 5 average rating,  6 reviews
# 159          Farm stay in Manali    4.8 out of 5 average rating,  10 reviews
# 160            Cottage in Manali     5.0 out of 5 average rating,  9 reviews
# 161  Bed and breakfast in Manali   4.8 out of 5 average rating,  122 reviews
#
#                           Prices  \
# ...

# %%
df.head()
# Out:
#                 Names                                    Reviews  \
# 0      Flat in Arpora                          New place to stay
# 1  Cottage in Assagao  4.72 out of 5 average rating,  60 reviews
# 2    Flat in Candolim    5.0 out of 5 average rating,  4 reviews
# 3      Home in Anjuna  4.75 out of 5 average rating,  12 reviews
# 4      Room in Morjim  4.87 out of 5 average rating,  30 reviews
#
#                         Prices  \
# 0  ₹16,929Show price breakdown
# 1  ₹13,866Show price breakdown
# 2  ₹10,044Show price breakdown
# 3  ₹18,400Show price breakdown
# 4   ₹8,895Show price breakdown
#
#                                                Links
# 0  https://www.airbnb.co.in/rooms/148526477405345...
# 1  https://www.airbnb.co.in/rooms/929315133354420...
# 2  https://www.airbnb.co.in/rooms/141020906377713...
# 3  https://www.airbnb.co.in/rooms/138916199527099...
# 4  https://www.airbnb.co.in/rooms/46291513?check_...

# %%
df[["Rating", "People_Reviewed"]] = df["Reviews"].str.split(",", expand= True)
df
# Out:
#                            Names                                     Reviews  \
# 0                 Home in Manali   4.98 out of 5 average rating,  49 reviews
# 1                Room in Vashist   4.97 out of 5 average rating,  34 reviews
# 2                 Room in Manali    4.8 out of 5 average rating,  69 reviews
# 3           Farm stay in Vashist  4.98 out of 5 average rating,  220 reviews
# 4                 Flat in Manali                           New place to stay
# ..                           ...                                         ...
# 157            Cottage in Manali   4.91 out of 5 average rating,  33 reviews
# 158               Home in Manali     5.0 out of 5 average rating,  6 reviews
# 159          Farm stay in Manali    4.8 out of 5 average rating,  10 reviews
# 160            Cottage in Manali     5.0 out of 5 average rating,  9 reviews
# 161  Bed and breakfast in Manali   4.8 out of 5 average rating,  122 reviews
#
#                           Prices  \
# ...

# %%
import numpy as np
def extract(value):
    try:
        return value[:value.index("out") - 1]
    except:
        return np.nan

df["Rating"] = df["Rating"].apply(extract)

# %%
def extract(value):
    try:
        return value[:value.index("rev") - 1]
    except:
        return np.nan

df["People_Reviewed"] = df["People_Reviewed"].apply(extract)
df
# Out:
#                            Names                                     Reviews  \
# 0                 Home in Manali   4.98 out of 5 average rating,  49 reviews
# 1                Room in Vashist   4.97 out of 5 average rating,  34 reviews
# 2                 Room in Manali    4.8 out of 5 average rating,  69 reviews
# 3           Farm stay in Vashist  4.98 out of 5 average rating,  220 reviews
# 4                 Flat in Manali                           New place to stay
# ..                           ...                                         ...
# 157            Cottage in Manali   4.91 out of 5 average rating,  33 reviews
# 158               Home in Manali     5.0 out of 5 average rating,  6 reviews
# 159          Farm stay in Manali    4.8 out of 5 average rating,  10 reviews
# 160            Cottage in Manali     5.0 out of 5 average rating,  9 reviews
# 161  Bed and breakfast in Manali   4.8 out of 5 average rating,  122 reviews
#
#                           Prices  \
# ...

# %%
def extract(value):
    try:
        return value[:value.index("Show")]
    except:
        return np.nan

df["Prices"] = df["Prices"].apply(extract)
df
# Out:
#                            Names                                     Reviews  \
# 0                 Home in Manali   4.98 out of 5 average rating,  49 reviews
# 1                Room in Vashist   4.97 out of 5 average rating,  34 reviews
# 2                 Room in Manali    4.8 out of 5 average rating,  69 reviews
# 3           Farm stay in Vashist  4.98 out of 5 average rating,  220 reviews
# 4                 Flat in Manali                           New place to stay
# ..                           ...                                         ...
# 157            Cottage in Manali   4.91 out of 5 average rating,  33 reviews
# 158               Home in Manali     5.0 out of 5 average rating,  6 reviews
# 159          Farm stay in Manali    4.8 out of 5 average rating,  10 reviews
# 160            Cottage in Manali     5.0 out of 5 average rating,  9 reviews
# 161  Bed and breakfast in Manali   4.8 out of 5 average rating,  122 reviews
#
# ...

# %%
df = df.drop(columns= "Reviews")
df
# Out:
#                            Names   Prices  \
# 0                 Home in Manali   ₹5,340
# 1                Room in Vashist   ₹7,200
# 2                 Room in Manali   ₹7,560
# 3           Farm stay in Vashist  ₹14,800
# 4                 Flat in Manali  ₹12,325
# ..                           ...      ...
# 157            Cottage in Manali  ₹22,945
# 158               Home in Manali  ₹14,327
# 159          Farm stay in Manali  ₹58,223
# 160            Cottage in Manali  ₹80,412
# 161  Bed and breakfast in Manali  ₹16,294
#
#                                                  Links Rating People_Reviewed
# 0    https://www.airbnb.co.in/rooms/650350723684946...   4.98              49
# 1    https://www.airbnb.co.in/rooms/38196172?check_...   4.97              34
# 2    https://www.airbnb.co.in/rooms/49156229?check_...    4.8              69
# 3    https://www.airbnb.co.in/rooms/30895371?check_...   4.98             220
# ...

# %%
df["Prices"] = df["Prices"].str.replace("₹", "")
df["Prices"] = df["Prices"].str.replace(",", "")
df
# Out:
#                            Names Prices  \
# 0                 Home in Manali   5340
# 1                Room in Vashist   7200
# 2                 Room in Manali   7560
# 3           Farm stay in Vashist  14800
# 4                 Flat in Manali  12325
# ..                           ...    ...
# 157            Cottage in Manali  22945
# 158               Home in Manali  14327
# 159          Farm stay in Manali  58223
# 160            Cottage in Manali  80412
# 161  Bed and breakfast in Manali  16294
#
#                                                  Links Rating People_Reviewed
# 0    https://www.airbnb.co.in/rooms/650350723684946...   4.98              49
# 1    https://www.airbnb.co.in/rooms/38196172?check_...   4.97              34
# 2    https://www.airbnb.co.in/rooms/49156229?check_...    4.8              69
# 3    https://www.airbnb.co.in/rooms/30895371?check_...   4.98             220
# 4    https://www.airbnb.co.in/rooms/149426524459824...    NaN             NaN
# ...

# %%
df.columns
# Out:
# Index(['Names', 'Prices', 'Links', 'Rating', 'People_Reviewed'], dtype='object')

# %%
x = ["Prices",'Rating', 'People_Reviewed']

for i in x:
    df[i] = df[i].astype("float")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Names            162 non-null    object
#  1   Prices           162 non-null    float64
#  2   Links            162 non-null    object
#  3   Rating           144 non-null    float64
#  4   People_Reviewed  144 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 6.5+ KB

# %%
df.to_csv("Airbnb_Manali_Listings.csv")
