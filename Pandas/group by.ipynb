# %%
import pandas as pd
import numpy as np

df = pd.read_csv("mxmh_survey_results.csv")
df
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# ...

# %%
gb = df.groupby(["Fav genre","Primary streaming service"]).agg({"Hours per day":"count"})
gb = gb.sort_values(by = "Hours per day")
gb
# Out:
#                                              Hours per day
# Fav genre Primary streaming service
# Lofi      Apple Music                                    1
# Folk      Apple Music                                    1
# K pop     Apple Music                                    1
# Lofi      Other streaming service                        1
# Gospel    I do not use a streaming service.              1
# ...                                                    ...
# Classical Spotify                                       25
# Hip hop   Spotify                                       28
# Metal     Spotify                                       61
# Pop       Spotify                                       68
# Rock      Spotify                                      118
#
# [74 rows x 1 columns]

# %%
df = pd.read_csv("Diwali sales data.csv", encoding='unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
gb = df.groupby(["Zone","Gender"]).agg({"Amount":"sum", "Orders":"sum"})
gb
# Out:
#                       Amount  Orders
# Zone     Gender
# Central  F       28820668.45    7370
#          M       12780205.00    3270
# Eastern  F        4773556.00    1416
#          M        2275657.00     599
# Northern F        8555306.00    2564
#          M        4063446.00    1163
# Southern F       18793087.98    4645
#          M        7813581.00    2099
# Western  F       13393238.00    3573
#          M        4980387.00    1308
