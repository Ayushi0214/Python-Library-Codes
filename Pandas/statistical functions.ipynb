# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Grocery.csv")
df
# Out:
#       Product Name  Price (USD)  Quantity Sold
# 0           Apples         1.99            150
# 1          Bananas         0.59            200
# 2          Carrots         0.89            250
# 3         Tomatoes         2.49            180
# 4         Potatoes         1.29            300
# 5           Onions         0.79            270
# 6         Broccoli         2.19            130
# 7          Spinach         1.99            220
# 8             Milk         3.49            190
# 9             Eggs         2.99            160
# 10           Bread         2.49             80
# 11  Chicken Breast         5.99             60
# 12     Ground Beef         6.99             50
# 13          Salmon        10.99             40
# 14          Yogurt         0.99            300
# 15          Cheese         4.49            230
# 16    Orange Juice         3.99            120
# 17          Coffee         9.99             70
# 18            Rice         1.49            500
# ...

# %%
df["Quantity Sold"].mean()
# Out:
# 197.5

# %%
df["Quantity Sold"].median()
# Out:
# 185.0

# %%
df["Quantity Sold"].mode()
# Out:
# 0    300
# Name: Quantity Sold, dtype: int64

# %%
df["Quantity Sold"].std()
# Out:
# 124.81038249659909

# %%
df = pd.read_csv("food_data.csv")
df.columns.values
# Out:
# array(['Unnamed: 0.1', 'Unnamed: 0', 'food', 'Caloric Value', 'Fat',
#        'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
#        'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber',
#        'Cholesterol', 'Sodium', 'Water', 'Vitamin A', 'Vitamin B1',
#        'Vitamin B11', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3',
#        'Vitamin B5', 'Vitamin B6', 'Vitamin C', 'Vitamin D', 'Vitamin E',
#        'Vitamin K', 'Calcium', 'Copper', 'Iron', 'Magnesium', 'Manganese',
#        'Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density'],
#       dtype=object)

# %%
df = df[['Caloric Value', 'Fat',
       'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats',
       'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber',
       'Cholesterol', 'Sodium', 'Water', 'Vitamin A', 'Vitamin B1',
       'Vitamin B11', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3',
       'Vitamin B5', 'Vitamin B6', 'Vitamin C', 'Vitamin D', 'Vitamin E',
       'Vitamin K', 'Calcium', 'Copper', 'Iron', 'Magnesium', 'Manganese',
       'Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density']]
df.corr()
# Out:
#                       Caloric Value       Fat  Saturated Fats  \
# Caloric Value              1.000000  0.909024        0.665258
# Fat                        0.909024  1.000000        0.795589
# Saturated Fats             0.665258  0.795589        1.000000
# Monounsaturated Fats       0.704331  0.791240        0.663787
# Polyunsaturated Fats       0.758928  0.716734        0.324472
# Carbohydrates              0.625024  0.471527        0.331421
# Sugars                     0.410723  0.288702        0.154351
# Protein                    0.598893  0.406726        0.179620
# Dietary Fiber              0.304923  0.198173        0.094875
# Cholesterol                0.536724  0.475149        0.314183
# Sodium                     0.389545  0.357115        0.300447
# Water                      0.405008  0.225564        0.038120
# Vitamin A                  0.271866  0.320395        0.343742
# Vitamin B1                 0.424174  0.337884        0.208898
# ...
